# %%
import pandas as pd
import numpy as np

from pprint import pprint as pp
from inspect import signature

# %%
df = pd.read_csv('../doit_pandas/data/scientists.csv')
df
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
Born = df['Born']
Died = df['Died']

# %%
Born
# Out:
# 0    1920-07-25
# 1    1876-06-13
# 2    1820-05-12
# 3    1867-11-07
# 4    1907-05-27
# 5    1813-03-15
# 6    1912-06-23
# 7    1777-04-30
# Name: Born, dtype: object

# %%
Died
# Out:
# 0    1958-04-16
# 1    1937-10-16
# 2    1910-08-13
# 3    1934-07-04
# 4    1964-04-14
# 5    1858-06-16
# 6    1954-06-07
# 7    1855-02-23
# Name: Died, dtype: object

# %%
# %timeit pd.to_datetime(Born, format='%Y-%m-%d')
# Out:
# 339 µs ± 17.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
pd.to_datetime(Born, format='%Y-%m-%d')
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
# %timeit pd.to_datetime(Died, format='%Y-%m-%d')
# Out:
# 346 µs ± 31.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
Born_datetime = pd.to_datetime(Born, format='%Y-%m-%d')
Died_datetime = pd.to_datetime(Died, format='%Y-%m-%d')

# %%
df['born_dt'] = np.nan

# %%
# del df['born_dt']
df
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
df['boan_dt'], df['died_dt'] = np.nan, np.nan

# %%
df
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#    boan_dt  died_dt
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
# 5      NaN      NaN
# 6      NaN      NaN
# 7      NaN      NaN

# %%
# df['boan_dt']
# df[['boan_dt', 'died_dt']]
# del df[['boan_dt', 'died_dt']]   # XX
del df['boan_dt'], df['died_dt']

# %%
df
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
dir()
# Out:
# ['Born',
#  'Born_datetime',
#  'Died',
#  'Died_datetime',
#  'In',
#  'Out',
#  '_',
#  '_10',
#  '_11',
#  '_12',
#  '_14',
#  '_18',
#  '_2',
#  '_22',
#  '_24',
#  '_27',
#  '_28',
#  '_29',
#  '_32',
#  '_5',
#  '_6',
#  '_7',
#  '_8',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'df',
#  'exit',
#  'get_ipython',
#  'np',
#  'pd',
#  'pp',
#  'quit',
#  'signature']

# %%
df['boan_dt'] = Born_datetime
df['died_dt'] = Died_datetime

df
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      boan_dt    died_dt
# 0 1920-07-25 1958-04-16
# 1 1876-06-13 1937-10-16
# 2 1820-05-12 1910-08-13
# 3 1867-11-07 1934-07-04
# 4 1907-05-27 1964-04-14
# 5 1813-03-15 1858-06-16
# 6 1912-06-23 1954-06-07
# 7 1777-04-30 1855-02-23

# %%
del df['boan_dt'], df['died_dt']
df
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
df['born_dt'], df['died_dt'] = (Born_datetime, Died_datetime)

df
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   45             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   90        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   61           Biologist
# 5             John Snow  1813-03-15  1858-06-16   41           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   56  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   66       Mathematician
#
#      born_dt    died_dt
# 0 1920-07-25 1958-04-16
# 1 1876-06-13 1937-10-16
# 2 1820-05-12 1910-08-13
# 3 1867-11-07 1934-07-04
# 4 1907-05-27 1964-04-14
# 5 1813-03-15 1858-06-16
# 6 1912-06-23 1954-06-07
# 7 1777-04-30 1855-02-23

# %%
df.shape
# Out:
# (8, 7)

# %%
type(df['born_dt']), type(df['died_dt'])
# Out:
# (pandas.core.series.Series, pandas.core.series.Series)

# %%
df['born_dt'], df['died_dt']
# Out:
# (0   1920-07-25
#  1   1876-06-13
#  2   1820-05-12
#  3   1867-11-07
#  4   1907-05-27
#  5   1813-03-15
#  6   1912-06-23
#  7   1777-04-30
#  Name: born_dt, dtype: datetime64[ns],
#  0   1958-04-16
#  1   1937-10-16
#  2   1910-08-13
#  3   1934-07-04
#  4   1964-04-14
#  5   1858-06-16
#  6   1954-06-07
#  7   1855-02-23
#  Name: died_dt, dtype: datetime64[ns])

# %%
df['life_dt'] = df['died_dt'] - df['born_dt']

# %%
df
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   45             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   90        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   61           Biologist
# 5             John Snow  1813-03-15  1858-06-16   41           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   56  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   66       Mathematician
#
#      born_dt    died_dt    life_dt
# 0 1920-07-25 1958-04-16 13779 days
# 1 1876-06-13 1937-10-16 22404 days
# 2 1820-05-12 1910-08-13 32964 days
# 3 1867-11-07 1934-07-04 24345 days
# 4 1907-05-27 1964-04-14 20777 days
# 5 1813-03-15 1858-06-16 16529 days
# 6 1912-06-23 1954-06-07 15324 days
# ...

# %%
df['life_dt']
# Out:
# 0   13779 days
# 1   22404 days
# 2   32964 days
# 3   24345 days
# 4   20777 days
# 5   16529 days
# 6   15324 days
# 7   28422 days
# Name: life_dt, dtype: timedelta64[ns]

# %%
Age = df['Age']
Age
# Out:
# 0    66
# 1    56
# 2    41
# 3    77
# 4    90
# 5    45
# 6    37
# 7    61
# Name: Age, dtype: int64

# %%
import random

# %%
# random.seed(42)

# %%
random.shuffle(Age)
Age
# Out:
# 0    61
# 1    41
# 2    66
# 3    90
# 4    77
# 5    45
# 6    56
# 7    37
# Name: Age, dtype: int64

# %%
random.shuffle(df['Age'])

df
# Out:
# /usr/lib/python3.6/random.py:277: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[i], x[j] = x[j], x[i]
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   45             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   66               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   56             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   37           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
# ...

# %%
del df['born_dt'], df['died_dt'], df['life_dt']
df
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   45             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   90        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   37               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   77             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   61           Biologist
# 5             John Snow  1813-03-15  1858-06-16   41           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   56  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   66       Mathematician

# %%
dropped_df = df.drop(['born_dt', 'died_dt', 'life_dt'], axis=1)
dropped_df
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   45             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   66               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   56             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   90           Biologist
# 5             John Snow  1813-03-15  1858-06-16   37           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
