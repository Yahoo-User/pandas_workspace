# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from pprint import pprint as pp

# %%
sns.get_dataset_names()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file /usr/local/lib/python3.6/dist-packages/seaborn/utils.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df_tips = sns.load_dataset('tips')

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
pp(df_tips.columns)
pp(df_tips.index)
pp(df_tips.values)
pp(df_tips.keys())
pp(df_tips.shape)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
# RangeIndex(start=0, stop=244, step=1)
# array([[16.99, 1.01, 'Female', ..., 'Sun', 'Dinner', 2],
#        [10.34, 1.66, 'Male', ..., 'Sun', 'Dinner', 3],
#        [21.01, 3.5, 'Male', ..., 'Sun', 'Dinner', 3],
#        ...,
#        [22.67, 2.0, 'Male', ..., 'Sat', 'Dinner', 2],
#        [17.82, 1.75, 'Male', ..., 'Sat', 'Dinner', 2],
#        [18.78, 3.0, 'Female', ..., 'Thur', 'Dinner', 2]], dtype=object)
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
# (244, 7)

# %%
figure = plt.figure()
grid = figure.add_subplot()
# grid = figure.add_subplot(1,1,1)

# figure.clear()

grid.hist(df_tips['total_bill'], bins=10)
grid.set_title('- Histogram of Total Bill -')
grid.set_xlabel('Total Bill')
grid.set_ylabel('Frequency')

figure.tight_layout()

# %%
figure = plt.figure()

grid = figure.add_subplot()
# grid = figure.add_subplot(1,1,1)

grid.scatter(df_tips['total_bill'], df_tips['tip'])
grid.set_title('- Scatter Plot of Total Bill vs Tips -')
grid.set_xlabel('total bill')
grid.set_ylabel('tips')

figure.tight_layout()

# %%
df_tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
figure = plt.figure()

# grid = figure.add_subplot(1,1,1)
grid = figure.add_subplot()

grid.boxplot(
    [ 
        df_tips[ df_tips['sex'] == 'Female']['tip'],
        df_tips[ df_tips['sex'] == 'Male']['tip'] 
    ], labels=['Female', 'Male'])

grid.set_title('- boxplot of tips by sex -')
grid.set_xlabel('sex')
grid.set_ylabel('tip')

figure.tight_layout()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
def encode_sex(sex):
    print('- encode_sex({}) invoked.'.format(sex))
    
    if sex == 'Female':
        return 0
    else:
        return 1
    
    pass # encode_sex

# %%
# df_tips['sex'].apply(encode_sex)
df_tips['sex_color'] = df_tips['sex'].apply(encode_sex)
# Out:
# - encode_sex(Male) invoked.
# - encode_sex(Female) invoked.

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_color
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0
# 1         10.34  1.66    Male     No   Sun  Dinner     3         1
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1
# 242       17.82  1.75    Male     No   Sat  Dinner     2         1
# 243       18.78  3.00  Female     No  Thur  Dinner     2         0
#
# [244 rows x 8 columns]

# %%
figure = plt.figure()

# grid = figure.add_subplot(1,1,1)
grid = figure.add_subplot()

grid.scatter(
    x = df_tips['total_bill'],
    y = df_tips['tip'],
    s = df_tips['size'] * 10,
    c = df_tips['sex_color'],
    alpha = .5
)

grid.set_title('- Total Bill vs Tip colored by sex and sized by size -')
grid.set_xlabel('total bill')
grid.set_ylabel('tip')

figure.tight_layout()

figure.legend()   # XX
# figure.legend(
#     handles = (df_tips['total_bill'], df_tips['tip']),
#     labels = ('total_bill', 'tip'),
#     loc='lower right'
# )

# figure.clear()
# Out:
# No handles with labels found to put in legend.
